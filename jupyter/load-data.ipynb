# %%
#LoadData
import pandas as pd
chords = pd.read_csv("chord-fingers.csv", delimiter = ';')
chords
# Out:
#      CHORD_ROOT CHORD_TYPE   CHORD_STRUCTURE FINGER_POSITIONS  \
# 0            A#         13  1;3;5;b7;9;11;13      x,1,0,2,3,4
# 1            A#         13  1;3;5;b7;9;11;13      4,x,3,2,1,1
# 2            A#         13  1;3;5;b7;9;11;13      1,x,1,2,3,4
# 3            A#      7(#9)       1;3;5;b7;#9      x,1,0,2,4,3
# 4            A#      7(#9)       1;3;5;b7;#9      2,1,3,3,3,x
# ...         ...        ...               ...              ...
# 2627          G       sus4             1;4;5      x,1,2,3,4,1
# 2628          G       sus4             1;4;5      x,x,3,4,1,1
# 2629          G        6/9         1;3;5;6;9      2,1,1,1,3,4
# 2630          G        6/9         1;3;5;6;9      x,x,2,1,3,4
# 2631          G        6/9         1;3;5;6;9      x,2,1,1,3,4
#
#             NOTE_NAMES
# 0     A#,C##,G#,B#,F##
# 1     A#,G#,B#,C##,F##
# 2     A#,G#,C##,F##,B#
# 3     A#,C##,G#,B##,E#
# 4     A#,C##,G#,B##,E#
# ...                ...
# 2627         G,D,G,C,D
# 2628           G,C,D,G
# ...
